# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import joblib

# %%
df = pd.read_csv("homeprice.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area(sqr ft)")
plt.ylabel("price(Rs)")
plt.scatter(df.area,df.price, color="red" ,marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
#Save Trained Model Using joblib
joblib.dump(reg, 'model_predict_homeprice')
ml = joblib.load('model_predict_homeprice')
print(ml.predict([[5000]]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Save Trained Model Using joblib
# ----> 2 joblib.dump(reg, 'model_predict_homeprice')
#       3 ml = joblib.load('model_predict_homeprice')
#       4 print(ml.predict([[5000]]))
#
# NameError: name 'reg' is not defined

# %%
# %matplotlib inline
plt.xlabel('area', fontsize=20)
plt.ylabel('price', fontsize=30)
plt.scatter(df.area,df.price, color="red" ,marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
d = pd.read_csv("area.csv")
d.head(4)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540

# %%
price = reg.predict(d)

# %%
d['price'] = price
d
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
d.to_csv("prediction.csv", index=False)
